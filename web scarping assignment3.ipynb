# %%
# !pip install bs4
# !pip install requests

# %%
# !pip install selenium

# %%
#import all the required libraries
import pandas as pd
import selenium
from selenium.webdriver.common.by import By
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# %%
import requests
from selenium import webdriver

browser = webdriver.Chrome()

browser.get("https://www.Amazon.in/")
from bs4 import BeautifulSoup
browser.maximize_window()

# %%
#locating the search bar
search_bar = browser.find_element(By.ID, "twotabsearchtextbox")   # Locating searc_bar by id
search_bar.clear()                                               # clearing search_bar
search_bar.send_keys("guitar")                                   # sending user input to search bar
search_button = browser.find_element(By.XPATH,'//span[@id="nav-search-submit-text"]')       # Locating search_button by xpath
search_button.click()

# %%
price=[]

prices=browser.find_elements(By.XPATH,"//span[@class='a-price-whole']")
for i in prices:
    price.append(i.text)

price
# Out:
# ['7,499',
#  '7,499',
#  '9,999',
#  '2,699',
#  '5,299',
#  '7,348',
#  '6,890',
#  '2,190',
#  '2,190',
#  '2,090',
#  '7,499',
#  '2,190',
#  '5,299',
#  '2,649',
#  '',
#  '26,999',
#  '19,800',
#  '16,818',
#  '18,988',
#  '',
#  '',
#  '',
#  '',
#  '2,649',
#  '2,699',
#  '2,190',
#  '2,649',
#  '2,699',
#  '2,649',
#  '5,999',
#  '2,649',
#  '4,699',
#  '4,490',
#  '2,699',
#  '2,699',
#  '3,790',
#  '4,999',
#  '6,499',
#  '7,599',
#  '989',
#  '2,649',
#  '2,699',
#  '2,649',
#  '2,699',
#  '2,699',
#  '3,179',
#  '2,499',
#  '6,916',
#  '2,699',
#  '6,299',
#  '3,850',
#  '2,499',
#  '2,655',
#  '789',
#  '239',
#  '4,280',
#  '12,400',
#  '3,919',
#  '999',
#  '5,000',
#  '3,850',
#  '5,500',
#  '6,410',
#  '6,400',
#  '649',
#  '9,990',
#  '19,800',
#  '7,499',
#  '2,699',
#  '999',
#  '1,199',
#  '989',
#  '949',
#  '588']

# %%
Title=[]


titles=browser.find_elements(By.XPATH,"//h2[@class='a-size-mini a-spacing-none a-color-base s-line-clamp-4']")
for i in titles:
    Title.append(i.text)
    
Title
# Out:
# ['Medellin 38" Acoustic Guitar Purple Burst Carbon Fiber body+(Free Online Learning Course) - Durable Matt finish with handrest, strings, strap, bag, 3 Picks, capo, stand.',
#  'Kadence Frontier guitar with Online Guitar learning course, Wine Red Acoustic Guitar with Die Cast Keys, Set of Strings, Strap, Picks and Bag (Wine Red, Acoustic)',
#  'Kadence Frontier Jumbo Semi Acoustic Guitar With Die Cast Keys Super Combo (Bag, 1 pack Strings, Strap, Picks, Capo, Tuner (natural)',
#  'Vault EA40 41 inch Premium Spruce-Top Cutaway Acoustic Guitar',
#  'Juarez Acoustic Guitar, 38 Inch Curved Body Cutaway, 38CUR with Bag, Strings, Pick and Strap, Black',
#  'Intern INT-38C Acoustic Guitar Kit, With Bag, Strings, Pick And Strap, Black',
#  'Intern 38C Cutaway Design Black Acoustic Guitar with Picks & Carry Bag',
#  'Epiphone PR-4E Acoustic-Electric Guitar Player Pack',
#  'Fender CD60s Dreadnought Acoustic Guitar (Mahagony)',
#  'Fender CD-60S Dreadnought Acoustic Guitar (Natural)',
# ...

# %%
#creating the empty list
Title=[]
Ratings=[]
price=[]
Rated=[]
Delivery=[]
images=[]
brands=[]

# %%
urls=browser.find_elements(By.XPATH,"//a[@class='a-link-normal a-text-normal']")
UR=[]
for i in urls:
    UR.append(i.get_attribute('href'))
for url in UR:
    browser.get(url)
    try:
        deliveries=browser.find_element(By.XPATH,"//div[@class='a-section a-spacing-mini']")
        Delivery.append(deliveries.text)
        rate=browser.find_element(By.XPATH,"//span[@id='acrCustomerReviewText']")
        rate.click()
        rating=browser.find_element(By.XPATH,"//span[@class='a-size-medium a-color-base']")
        Ratings.append(rating.text)
        rates=browser.find_element(By.XPATH,"//span[@class='a-size-base a-color-secondary']")
        Rated.append(rates.text)
    except NoSuchElementException   as e:
        Ratings.append("NO rating")#appending the No rating if no rating is there
        Rated.append("No rating")
        brands.append("No rating")
        Delivery.append("No rating")

# %%
url="https://www.amazon.in/s?k=guitar&ref=nb_sb_noss"
browser.get(url)
urls=browser.find_elements(By.XPATH,"//img[@class='s-image']")
images=[]
for i in urls:
    images.append(i.get_attribute('src'))
for url in images:
    browser.get(url)

# %%
Ratings
# Out:
# ['4 out of 5',
#  '4 out of 5',
#  '3.9 out of 5',
#  '3.9 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '3.9 out of 5',
#  '3.9 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '3.9 out of 5',
#  '3.9 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '4.3 out of 5',
#  '4.3 out of 5',
#  '3.5 out of 5',
#  '3.5 out of 5',
#  '3.5 out of 5',
#  '3.5 out of 5',
#  '3.9 out of 5',
#  '3.9 out of 5',
#  '4.3 out of 5',
#  '4.2 out of 5',
#  '4.4 out of 5',
#  '3.6 out of 5',
#  '4.2 out of 5',
#  '4.4 out of 5',
#  '4.3 out of 5',
#  '4 out of 5',
#  '3.9 out of 5',
#  '4 out of 5',
#  '3.9 out of 5',
#  '4 out of 5',
#  '3.9 out of 5',
#  '3.9 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '3.9 out of 5',
#  '3.9 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '3.9 out of 5',
#  '3.9 out of 5',
#  '4.4 out of 5',
#  '4.4 out of 5',
#  '4.3 out of 5',
#  '4.3 out of 5',
#  '4 out of 5',
#  '4 out of 5',
# ...

# %%
Rated
# Out:
# ['894 global ratings',
#  '894 global ratings',
#  'Total price:',
#  'Total price:',
#  'Total price:',
#  'Total price:',
#  'Total price:',
#  'Total price:',
#  '1,356 global ratings',
#  '1,356 global ratings',
#  '1,356 global ratings',
#  '1,356 global ratings',
#  'Total price:',
#  'Total price:',
#  'Total price:',
#  'Total price:',
#  'Total price:',
#  'Total price:',
#  'Total price:',
#  'Total price:',
#  'Total price:',
#  'Total price:',
#  '35 global ratings',
#  '35 global ratings',
#  'Total price:',
#  '178 global ratings',
#  'Total price:',
#  'Total price:',
#  'Total price:',
#  'Total price:',
#  'Total price:',
#  '1,356 global ratings',
#  'Total price:',
#  '354 global ratings',
#  'Total price:',
#  '1,027 global ratings',
#  'Total price:',
#  'Total price:',
#  'Total price:',
#  'Total price:',
#  'Total price:',
#  'Total price:',
#  '1,356 global ratings',
#  '1,356 global ratings',
#  '1,356 global ratings',
#  '1,356 global ratings',
# ...

# %%
Delivery
# Out:
# ['Ends in 10h 08m 31s',
#  'Ends in 10h 05m 47s',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Ends in 10h 05m 13s',
#  'Ends in 10h 05m 08s',
#  'Ends in 10h 05m 03s',
#  'Ends in 10h 04m 59s',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Ends in 10h 03m 42s',
#  '',
#  'Ends in 10h 03m 35s',
#  '',
#  'Ends in 10h 03m 27s',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Ends in 10h 03m 00s',
#  'Ends in 10h 02m 57s',
#  'Ends in 10h 02m 53s',
#  'Ends in 10h 02m 49s',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'No rating',
#  'No rating',
#  'No rating',
#  'No rating',
#  'No rating',
#  'No rating',
#  'No rating',
#  'No rating',
#  'No rating',
#  'No rating',
#  'No rating',
#  'No rating',
#  'No rating',
#  'No rating',
#  'No rating',
#  'No rating',
#  'No rating',
#  'No rating',
#  'No rating',
#  'No rating']

# %%
#checking the length of each list
print(len(Title))
print(len(price))
print(len(Ratings))
print(len(Delivery))
print(len(Rated))
print(len(images))
# Out:
# 0
# 0
# 78
# 78
# 78
# 72

# %%
import pandas as pd
amazon=pd.DataFrame({})
amazon['Titles']=Title[0:60]
amazon['Price']=price[0:60]
amazon['Ratings']=Ratings[0:60]
amazon['rates']=Rated[0:60]
amazon['delivery']=Delivery[0:60]
amazon['images']=images[0:60]
amazon
# Out:
#     Titles  Price       Ratings                 rates             delivery  \
# 0      NaN    NaN    4 out of 5    894 global ratings  Ends in 10h 08m 31s
# 1      NaN    NaN    4 out of 5    894 global ratings  Ends in 10h 05m 47s
# 2      NaN    NaN  3.9 out of 5          Total price:
# 3      NaN    NaN  3.9 out of 5          Total price:
# 4      NaN    NaN    4 out of 5          Total price:
# 5      NaN    NaN    4 out of 5          Total price:
# 6      NaN    NaN  3.9 out of 5          Total price:
# 7      NaN    NaN  3.9 out of 5          Total price:
# 8      NaN    NaN    4 out of 5  1,356 global ratings  Ends in 10h 05m 13s
# 9      NaN    NaN    4 out of 5  1,356 global ratings  Ends in 10h 05m 08s
# 10     NaN    NaN    4 out of 5  1,356 global ratings  Ends in 10h 05m 03s
# 11     NaN    NaN    4 out of 5  1,356 global ratings  Ends in 10h 04m 59s
# 12     NaN    NaN  3.9 out of 5          Total price:
# 13     NaN    NaN  3.9 out of 5          Total price:
# ...

# %%
url="https://www.amazon.in/s?k=guitar&page=2&qid=1619266454&ref=sr_pg_2"
browser.get(url)

# %%
prices=browser.find_elements(By.XPATH,"//span[@class='a-price-whole']")
for i in prices:
    price.append(i.text)
titles=browser.find_elements(By.XPATH,"//h2[@class='a-size-mini a-spacing-none a-color-base s-line-clamp-4']")
for i in titles:
    Title.append(i.text)

# %%
price
# Out:
# ['6,999',
#  '4,150',
#  '7,599',
#  '7,599',
#  '4,244',
#  '3,790',
#  '5,759',
#  '3,822',
#  '7,499',
#  '6,349',
#  '2,589',
#  '15,299',
#  '2,799',
#  '5,248',
#  '8,590',
#  '3,690',
#  '5,415',
#  '2,589',
#  '9,999',
#  '7,499',
#  '299',
#  '2,695',
#  '1,199',
#  '3,799',
#  '7,499',
#  '6,659',
#  '5,999',
#  '2,589',
#  '2,589',
#  '5,727',
#  '249',
#  '5,700',
#  '899',
#  '2,695',
#  '3,919',
#  '4,115',
#  '9,599',
#  '499',
#  '7,599',
#  '4,999',
#  '2,649',
#  '19,502',
#  '7,349',
#  '10,250',
#  '8,299',
#  '9,490',
#  '3,919',
#  '20,999',
#  '1,199',
#  '299',
#  '6,999',
#  '2,649',
#  '4,950',
#  '6,349',
#  '3,790',
#  '2,695',
#  '2,695',
#  '2,695',
#  '599',
#  '7,499',
#  '129.',
#  '299.',
#  '438.',
#  '129.',
#  '299.',
#  '395.',
#  '249.',
#  '699.',
#  '247.',
#  '1,799.',
#  '259.',
#  '1,599.',
#  '169.',
#  '1,449.',
#  '249.',
#  '399.',
#  '99.',
#  '1,299.',
#  '6,999',
#  '4,150',
#  '7,599',
#  '7,599',
#  '4,244',
#  '3,790',
# ...

# %%
Title
# Out:
# ['GUITAR BRO - COMBO (Blue Acoustic Guitar for Beginner, Guitar Learning Kit, Song Book, Video Lectures, Accessories like Pick, Bag)',
#  'Jyotaksh Store Givson Venus Special Guitar Combo Acoustic Guitar With Cover/Bag, String Set, Strap and 5 Plectrums (Blue, Venus Special)',
#  'Vault ST1 Premium Electric Guitar - Metallic Blue',
#  'Vault ST1 Strat Style 6 String Electric Guitar- Black',
#  'Intern Made in India Acoustic Guitar package. 39 inches Cutaway Guitar with Truss Rod. Durable and long lasting with Carry bag, strings, picks and allen key, red, full (INT-IN39C-RD)',
#  'Kordz Venus Black Matt Rosewood Fretboard Acoustic Guitar With Bag,Strap,1 Set of Extra Strings and 2 Picks',
#  'Juarez JRZ-ST01, 6 Strings Electric Guitar, Right Handed with Bag/Case, 2 x Picks (3TS Sunburst)',
# ...

# %%
urls=browser.find_elements(By.XPATH,"//a[@class='a-link-normal a-text-normal']")
UR=[]
for i in urls:
    UR.append(i.get_attribute('href'))
for url in UR:
    browser.get(url)
    try:
        deliveries=browser.find_element(By.XPATH,"//div[@class='a-section a-spacing-mini']")
        Delivery.append(deliveries.text)
        rate=browser.find_element(By.XPATH,"//span[@id='acrCustomerReviewText']")
        rate.click()
        rating=browser.find_element(By.XPATH,"//span[@class='a-size-medium a-color-base']")
        Ratings.append(rating.text)
        rates=browser.find_element(By.XPATH,"//span[@class='a-size-base a-color-secondary']")
        Rated.append(rates.text)
    except NoSuchElementException   as e:
        Ratings.append("NO rating")#appending the No rating if no rating is there
        Rated.append("No rating")
        brands.append("No rating")
        Delivery.append("No rating")

# %%
url="https://www.amazon.in/s?k=guitar&page=2&qid=1619266454&ref=sr_pg_2"
browser.get(url)
urls=browser.find_elements(By.XPATH,"//img[@class='s-image']")
images=[]
for i in urls:
    images.append(i.get_attribute('src'))
for url in images:
    browser.get(url)

# %%
images
# Out:
# ['https://m.media-amazon.com/images/I/41LgRIBig8L._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/41vdAWvrl-L._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/41Nmu0pShaL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/41ktFqEFfpL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71vuHCWEHkL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/613FhDUYQbL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71OXkf-hRxL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/817YUW6Em6L._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/41vyC7nVH4L._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/712o5iXpjjL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71ryDZYzsFL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/717nfJdku6L._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71GtDNhYKaL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71cVdbeHrOL._AC_UL320_.jpg',
# ...

# %%
print(len(Title))
print(len(price))
print(len(Ratings))
print(len(Delivery))
print(len(Rated))
print(len(images))
# Out:
# 120
# 234
# 94
# 94
# 94
# 60

# %%
import pandas as pd
amazon=pd.DataFrame({})
amazon['Titles']=Title[0:60]
amazon['Price']=price[0:60]
amazon['Ratings']=Ratings[0:60]
amazon['rates']=Rated[0:60]
amazon['delivery']=Delivery[0:60]
amazon['images']=images[0:60]
amazon
# Out:
#                                                Titles   Price       Ratings  \
# 0   GUITAR BRO - COMBO (Blue Acoustic Guitar for B...   6,999    4 out of 5
# 1   Jyotaksh Store Givson Venus Special Guitar Com...   4,150    4 out of 5
# 2   Vault ST1 Premium Electric Guitar - Metallic Blue   7,599  3.9 out of 5
# 3   Vault ST1 Strat Style 6 String Electric Guitar...   7,599  3.9 out of 5
# 4   Intern Made in India Acoustic Guitar package. ...   4,244    4 out of 5
# 5   Kordz Venus Black Matt Rosewood Fretboard Acou...   3,790    4 out of 5
# 6   Juarez JRZ-ST01, 6 Strings Electric Guitar, Ri...   5,759  3.9 out of 5
# 7   JUAREZ Fiésta 41 Inch Acoustic Guitar Cutaway ...   3,822  3.9 out of 5
# 8   Kadence AstroMan Electric Guitar, 21 FRETS, RO...   7,499    4 out of 5
# 9   Martin Smith W-101-Bl-PK Acoustic Guitar Super...   6,349    4 out of 5
# 10  INTERN Cutaway Design Acoustic Guitar Pack -Hu...   2,589    4 out of 5
# ...

# %%
url="https://www.amazon.in/s?k=guitar&page=3&qid=1619266730&ref=sr_pg_3"
browser.get(url)

# %%
prices=browser.find_elements(By.XPATH,"//span[@class='a-price-whole']")
for i in prices:
    price.append(i.text)
titles=browser.find_elements(By.XPATH,"//h2[@class='a-size-mini a-spacing-none a-color-base s-line-clamp-4']")
for i in titles:
    Title.append(i.text)

# %%
urls=browser.find_elements(By.XPATH,"//a[@class='a-link-normal a-text-normal']")
UR=[]
for i in urls:
    UR.append(i.get_attribute('href'))
for url in UR:
    browser.get(url)
    try:
        deliveries=browser.find_element(By.XPATH,"//div[@class='a-section a-spacing-mini']")
        Delivery.append(deliveries.text)
        rate=browser.find_element(By.XPATH,"//span[@id='acrCustomerReviewText']")
        rate.click()
        rating=browser.find_element(By.XPATH,"//span[@class='a-size-medium a-color-base']")
        Ratings.append(rating.text)
        rates=browser.find_element(By.XPATH,"//span[@class='a-size-base a-color-secondary']")
        Rated.append(rates.text)
    except NoSuchElementException   as e:
        Ratings.append("NO rating")#appending the No rating if no rating is there
        Rated.append("No rating")
        brands.append("No rating")
        Delivery.append("No rating")

# %%
url="https://www.amazon.in/s?k=guitar&page=3&qid=1619266730&ref=sr_pg_3"
browser.get(url)
urls=browser.find_elements(search_bar = browser.find_element_by_xpath('//input[@class="gLFyf gsfi"]')    # Locating searc_bar by id
search_bar.clear()                                               # clearing search_bar
search_bar.send_keys(input("Enter your Search:"))                                   # sending user input to search ba
search_button = browser.find_element_by_xpath('//span[@class="z1asCe MZy1Rb"]')       # Locating search_button by xpath
search_button.click()"//img[@class='s-image']")
images=[]
for i in urls:
    images.append(i.get_attribute('src'))
for url in images:
    browser.get(url)

# %%
print(len(Title))
print(len(price))
print(len(Ratings))
print(len(Delivery))
print(len(Rated))
print(len(images))
# Out:
# 180
# 308
# 108
# 108
# 108
# 60

# %%
import pandas as pd
amazon=pd.DataFrame({})
amazon['Titles']=Title[0:56]
amazon['Price']=price[0:56]
amazon['Ratings']=Ratings[0:56]
amazon['rates']=Rated[0:56]
amazon['delivery']=Delivery[0:56]
amazon['images']=images[0:56]
amazon
# Out:
#                                                Titles   Price       Ratings  \
# 0   GUITAR BRO - COMBO (Blue Acoustic Guitar for B...   6,999    4 out of 5
# 1   Jyotaksh Store Givson Venus Special Guitar Com...   4,150    4 out of 5
# 2   Vault ST1 Premium Electric Guitar - Metallic Blue   7,599  3.9 out of 5
# 3   Vault ST1 Strat Style 6 String Electric Guitar...   7,599  3.9 out of 5
# 4   Intern Made in India Acoustic Guitar package. ...   4,244    4 out of 5
# 5   Kordz Venus Black Matt Rosewood Fretboard Acou...   3,790    4 out of 5
# 6   Juarez JRZ-ST01, 6 Strings Electric Guitar, Ri...   5,759  3.9 out of 5
# 7   JUAREZ Fiésta 41 Inch Acoustic Guitar Cutaway ...   3,822  3.9 out of 5
# 8   Kadence AstroMan Electric Guitar, 21 FRETS, RO...   7,499    4 out of 5
# 9   Martin Smith W-101-Bl-PK Acoustic Guitar Super...   6,349    4 out of 5
# 10  INTERN Cutaway Design Acoustic Guitar Pack -Hu...   2,589    4 out of 5
# ...

# %%
#import all the required libraries
import pandas as pd
import selenium
from selenium.webdriver.common.by import By
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# %%
import requests
from selenium import webdriver

browser = webdriver.Chrome()

browser.get("https://images.google.com/")
browser.maximize_window()

# %%
search_bar = browser.find_element(By.XPATH,'//input[@class="gLFyf gsfi"]')    # Locating searc_bar by id
search_bar.clear()                                               # clearing search_bar
search_bar.send_keys(input("Enter your Search:"))                                   # sending user input to search ba
search_button = browser.find_element(By.XPATH,'//span[@class="z1asCe MZy1Rb"]')       # Locating search_button by xpath
search_button.click()

# %%
Taking the all required codes but not working.

# %%
urls=browser.find_elements_by_xpath("//img[@class='rg_i Q4LuWd']")#collecting urls of all the laptop
images=[]
for i in urls:
    images.append(i.get_attribute('src'))#getting the url of first 10 laptops
len(images)

# %%
urls=browser.find_elements_by_xpath("//a[@class='VFACy kGQAp sMi44c lNHeqe WGvvNb']")#collecting urls of all the laptop
headers=[]
for i in urls:
    headers.append(i.get_attribute('href'))#getting the url of first 10 laptops
len(headers)

# %%
google=pd.DataFrame({})
google['Headers']=headers
google['images']=images[0:100]
google

# %% [markdown]
# # Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on
# www.flipkart.com and scrape following details for all the search results displayed on 1st page. Details to be
# scraped: “Brand Name”, “Smartphone name”, “Colour”, “RAM”, “Storage(ROM)”, “Primary Camera”,
# “Secondary Camera”, “Display Size”, “Battery Capacity”, “Price”, “Product URL”. Incase if any of the
# details is missing then replace it by “- “. Save your results in a dataframe and CSV.

# %%
#import all the required libraries
import pandas as pd
import selenium
from selenium.webdriver.common.by import By
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# %%
import requests
from selenium import webdriver

browser = webdriver.Chrome()

browser.get("https://www.flipkart.com/")
browser.maximize_window()

# %%
search_bar = browser.find_element(By.CLASS_NAME, '_3704LK')
search_bar.send_keys("Vivo Mobile Phone")

# %%
button_1 = browser.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input')
button_1.click()
browser.implicitly_wait(3)

# %%
click_button = browser.find_element(By.CLASS_NAME,"L0Z3Pu")
click_button.click()

# %%
Brand =[]
br = browser.find_elements(By.XPATH,"//div[@class='_4rR01T']")
for i in br:
    try:
        Brand.append(i.text)#appending the ratings in Ratings list

        

    except:
        Brand.append("_")#appending the No rating if no rating is there

# %%
len(Brand)
# Out:
# 24

# %%
Brand
# Out:
# ['vivo T1 5G (Rainbow Fantasy, 128 GB)',
#  'vivo T1 5G (Rainbow Fantasy, 128 GB)',
#  'vivo T1 5G (Starlight Black, 128 GB)',
#  'vivo T1 5G (Starlight Black, 128 GB)',
#  'vivo T1 5G (Rainbow Fantasy, 128 GB)',
#  'vivo Y20G 2021 (Obsidian Black, 64 GB)',
#  'vivo Y21T (Pearl White, 128 GB)',
#  'vivo V23 5G (Sunshine Gold, 128 GB)',
#  'vivo V23 5G (Stardust Black, 256 GB)',
#  'vivo Y21 (Diamond Glow, 64 GB)',
#  'vivo V23 5G (Stardust Black, 128 GB)',
#  'vivo Y21T (Midnight Blue, 128 GB)',
#  'vivo V23 5G (Sunshine Gold, 256 GB)',
#  'vivo Y21A (Midnight Blue, 64 GB)',
#  'vivo Y21A (Diamond Glow, 64 GB)',
#  'vivo Y21 (Midnight Blue, 64 GB)',
#  'vivo Y3s (Mint Green, 32 GB)',
#  'vivo Y33s (Midday Dream, 128 GB)',
#  'vivo Y33s (Mirror Black, 128 GB)',
#  'vivo Y12G (Phantom Black, 32 GB)',
#  'vivo Y12G (Glacier Blue, 32 GB)',
#  'vivo Y73 (Diamond Flare, 128 GB)',
#  'vivo Y73 (Roman Black, 128 GB)',
#  'vivo Y12G (Phantom Black, 64 GB)']

# %%
ratings=[]
rating=browser.find_elements(By.CLASS_NAME,'_1lRcqv')#scraping description by class name = '_2mylT6'
for i in rating:
    try:
        ratings.append(i.text)#appending the ratings in Ratings list

        

    except:
        ratings.append("_")#appending the No rating if no rating is there

# %%
len(ratings)
# Out:
# 24

# %%
ratings
# Out:
# ['4.4',
#  '4.4',
#  '4.3',
#  '4.4',
#  '4.3',
#  '4.3',
#  '4.4',
#  '4.4',
#  '4.3',
#  '4.3',
#  '4.4',
#  '4.4',
#  '4.3',
#  '4.5',
#  '4.5',
#  '4.3',
#  '4.4',
#  '4.3',
#  '4.3',
#  '4.3',
#  '4.3',
#  '4.4',
#  '4.4',
#  '4.3']

# %%
RAM=[]
RM=browser.find_elements(By.XPATH,"//ul[@class='_1xgFaf']/li[1]")
for i in RM:
    try:
        RAM.append(i.text)#appending the ratings in Ratings list

        

    except:
        RAM.append("_")#appending the No rating if no rating is there

# %%
Display_Size=[]
DS=browser.find_elements(By.XPATH,"//ul[@class='_1xgFaf']/li[2]")
for i in DS:
    try:
        Display_Size.append(i.text)#appending the ratings in Ratings list

        

    except:
        Display_Size.append("_")#appending the No rating if no rating is there
Display_Size
# Out:
# ['16.71 cm (6.58 inch) Full HD+ Display',
#  '16.71 cm (6.58 inch) Full HD+ Display',
#  '16.71 cm (6.58 inch) Full HD+ Display',
#  '16.71 cm (6.58 inch) Full HD+ Display',
#  '16.71 cm (6.58 inch) Full HD+ Display',
#  '16.54 cm (6.51 inch) HD+ Display',
#  '16.71 cm (6.58 inch) Full HD+ Display',
#  '16.36 cm (6.44 inch) Full HD+ Display',
#  '16.36 cm (6.44 inch) Full HD+ Display',
#  '16.54 cm (6.51 inch) HD+ Display',
#  '16.36 cm (6.44 inch) Full HD+ Display',
#  '16.71 cm (6.58 inch) Full HD+ Display',
#  '16.36 cm (6.44 inch) Full HD+ Display',
#  '16.54 cm (6.51 inch) HD+ Display',
#  '16.54 cm (6.51 inch) Display',
#  '16.54 cm (6.51 inch) HD+ Display',
#  '16.54 cm (6.51 inch) HD+ Display',
#  '16.71 cm (6.58 inch) Full HD+ Display',
#  '16.71 cm (6.58 inch) Full HD+ Display',
#  '16.54 cm (6.51 inch) HD+ Display',
#  '16.54 cm (6.51 inch) HD+ Display',
#  '16.36 cm (6.44 inch) Full HD+ Display',
#  '16.36 cm (6.44 inch) Full HD+ Display',
# ...

# %%
Camera=[]
cm=browser.find_elements(By.XPATH,"//ul[@class='_1xgFaf']/li[3]")
for i in cm:
    try:
        Camera.append(i.text)#appending the ratings in Ratings list

        

    except:
        Camera.append("_")#appending the No rating if no rating is there

# %%
Camera
# Out:
# ['50MP + 2MP + 2MP | 16MP Front Camera',
#  '50MP + 2MP + 2MP | 16MP Front Camera',
#  '50MP + 2MP + 2MP | 16MP Front Camera',
#  '50MP + 2MP + 2MP | 16MP Front Camera',
#  '50MP + 2MP + 2MP | 16MP Front Camera',
#  '13MP + 2MP + 2MP | 8MP Front Camera',
#  '50MP + 2MP + 2MP | 8MP Front Camera',
#  '64MP + 8MP + 2MP | 50MP + 8MP Dual Front Camera',
#  '64MP + 8MP + 2MP | 50MP + 8MP Dual Front Camera',
#  '13MP + 2MP | 8MP Front Camera',
#  '64MP + 8MP + 2MP | 50MP + 8MP Dual Front Camera',
#  '50MP + 2MP + 2MP | 8MP Front Camera',
#  '64MP + 8MP + 2MP | 50MP + 8MP Dual Front Camera',
#  '13MP + 2MP | 8MP + 8MP Dual Front Camera',
#  '13MP Rear Camera',
#  '13MP + 2MP | 8MP Front Camera',
#  '13MP Rear Camera | 5MP Front Camera',
#  '50MP + 2MP + 2MP | 16MP Front Camera',
#  '50MP + 2MP + 2MP | 16MP Front Camera',
#  '13MP + 2MP | 8MP Front Camera',
#  '13MP + 2MP | 8MP Front Camera',
#  '64MP + 2MP + 2MP | 16MP Front Camera',
#  '64MP + 2MP + 2MP | 16MP Front Camera',
# ...

# %%
Battery=[]
bt=browser.find_elements(By.XPATH,"//ul[@class='_1xgFaf']/li[4]")
for i in bt:
    try:
        Battery.append(i.text)#appending the ratings in Ratings list

        

    except:
        Battery.append("_")#appending the No rating if no rating is there
Battery
# Out:
# ['5000 mAh Lithium Battery',
#  '5000 mAh Lithium Battery',
#  '5000 mAh Lithium Battery',
#  '5000 mAh Lithium Battery',
#  '5000 mAh Lithium Battery',
#  '5000 mAh Li-ion Battery',
#  '5000 mAh Lithium Battery',
#  '4200 mAh Lithium Battery',
#  '4200 mAh Lithium Battery',
#  '5000 mAh Lithium Battery',
#  '4200 mAh Lithium Battery',
#  '5000 mAh Lithium Battery',
#  '4200 mAh Lithium Battery',
#  '5000 mAh Battery',
#  '5000 mAh Battery',
#  '5000 mAh Lithium Battery',
#  '5000 mAh Li-ion Battery',
#  '5000 mAh Lithium Battery',
#  '5000 mAh Lithium Battery',
#  '5000 mAh Li-ion Battery',
#  '5000 mAh Li-ion Battery',
#  '4000 mAh Battery',
#  '4000 mAh Battery',
#  '5000 mAh Li-ion Battery']

# %%
Warranty=[]
wy=browser.find_elements(By.XPATH,"//ul[@class='_1xgFaf']/li[5]")
for i in wy:
    try:
        Warranty.append(i.text)#appending the ratings in Ratings list

        

    except:
        Warranty.append("_")#appending the No rating if no rating is there
Warranty
# Out:
# ['Qualcomm Snapdragon 695 Processor',
#  'Qualcomm Snapdragon 695 Processor',
#  'Qualcomm Snapdragon 695 Processor',
#  'Qualcomm Snapdragon 695 Processor',
#  'Qualcomm Snapdragon 695 Processor',
#  'MediaTek Helio P35 Processor',
#  'Qualcomm Snapdragon 680 Processor',
#  'Mediatek Dimensity 920 Processor',
#  'Mediatek Dimensity 920 Processor',
#  'Mediatek Helio P35 Processor',
#  'Mediatek Dimensity 920 Processor',
#  'Qualcomm Snapdragon 680 Processor',
#  'Mediatek Dimensity 920 Processor',
#  'Mediatek Helio P22 Processor',
#  '1 Year for Handset and 6 Months for Inbox Accessories',
#  'Mediatek Helio P35 Processor',
#  'Mediatek Helio P35 Processor',
#  'MediaTek Helio G80 Processor',
#  'MediaTek Helio G80 Processor',
#  'Qualcomm Snapdragon 439 Processor',
#  'Qualcomm Snapdragon 439 Processor',
#  'MediaTek Helio G95 Processor',
#  'MediaTek Helio G95 Processor',
#  'Qualcomm Snapdragon 439 Processor']

# %%
Prices=[]
pr=browser.find_elements(By.XPATH,"//div[@class='_30jeq3 _1_WHN1']")
for i in pr:
    try:
        Prices.append(i.text)#appending the ratings in Ratings list

        

    except:
        Prices.append("_")#appending the No rating if no rating is there
Prices
# Out:
# ['₹16,990',
#  '₹15,990',
#  '₹19,990',
#  '₹15,990',
#  '₹19,990',
#  '₹13,990',
#  '₹16,490',
#  '₹29,990',
#  '₹34,990',
#  '₹13,990',
#  '₹29,990',
#  '₹16,490',
#  '₹34,990',
#  '₹13,890',
#  '₹13,873',
#  '₹13,990',
#  '₹10,299',
#  '₹18,990',
#  '₹18,990',
#  '₹10,990',
#  '₹10,990',
#  '₹20,990',
#  '₹20,990',
#  '₹11,990']

# %%
flipkart=pd.DataFrame({})
flipkart['brand']=Brand
flipkart['ratings']=ratings
flipkart['inches']=Display_Size
flipkart['camera']=Camera
flipkart['price']=Prices
flipkart['Ram']=RAM
flipkart['battery']=Battery
flipkart['warranty']=Warranty

# %%
flipkart
# Out:
#                                      brand ratings  \
# 0     vivo T1 5G (Rainbow Fantasy, 128 GB)     4.4
# 1     vivo T1 5G (Rainbow Fantasy, 128 GB)     4.4
# 2     vivo T1 5G (Starlight Black, 128 GB)     4.3
# 3     vivo T1 5G (Starlight Black, 128 GB)     4.4
# 4     vivo T1 5G (Rainbow Fantasy, 128 GB)     4.3
# 5   vivo Y20G 2021 (Obsidian Black, 64 GB)     4.3
# 6          vivo Y21T (Pearl White, 128 GB)     4.4
# 7      vivo V23 5G (Sunshine Gold, 128 GB)     4.4
# 8     vivo V23 5G (Stardust Black, 256 GB)     4.3
# 9           vivo Y21 (Diamond Glow, 64 GB)     4.3
# 10    vivo V23 5G (Stardust Black, 128 GB)     4.4
# 11       vivo Y21T (Midnight Blue, 128 GB)     4.4
# 12     vivo V23 5G (Sunshine Gold, 256 GB)     4.3
# 13        vivo Y21A (Midnight Blue, 64 GB)     4.5
# 14         vivo Y21A (Diamond Glow, 64 GB)     4.5
# 15         vivo Y21 (Midnight Blue, 64 GB)     4.3
# 16            vivo Y3s (Mint Green, 32 GB)     4.4
# ...

# %% [markdown]
# # Write a program to scrap details of all the funding deals for second quarter (i.e Jan 21 – March 21)
# from trak.in

# %%
#import all the required libraries
import pandas as pd
import selenium
from selenium.webdriver.common.by import By
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# %%
import requests
from selenium import webdriver

browser = webdriver.Chrome()

browser.get("https://trak.in/india-startup-funding-investment-2015/")
browser.maximize_window()

# %%
title_tags = browser.find_elements(By.XPATH,"//div[@class='dataTables_scroll']")
title_tags
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="dbb3eb1fa91c9fdcecb75e6ce8857764", element="530b15a3-0f31-4514-8bfe-0c5a6f6ad723")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dbb3eb1fa91c9fdcecb75e6ce8857764", element="f542961a-50f4-4b6c-9c9b-b2b19e1fed2a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dbb3eb1fa91c9fdcecb75e6ce8857764", element="05f1459a-c407-4415-8d8a-2c5dd2a6de89")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dbb3eb1fa91c9fdcecb75e6ce8857764", element="8437c012-a01b-4317-869f-a409049bf273")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dbb3eb1fa91c9fdcecb75e6ce8857764", element="2a3c1b83-eb1e-4659-a8c4-9210b837eafd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dbb3eb1fa91c9fdcecb75e6ce8857764", element="4db3b79e-c981-49a2-b1b1-079389e000e8")>,
# ...

# %%
titles=[]
for i in title_tags:
    title=i.text
    titles.append(title)

# %%
#scraping from  Jan 21 – March 21
titles[7:9]
# Out:
# ["Sr. No. Date (dd/mm/yyyy) Startup Name Industry / Vertical Sub-Vertical City / Location Investors' Name Investment Type Amount (In USD)\n1 08/09/2020 Byju’s EduTech Online Tutoring Bangalore Silver Lake, Tiger Global, General Atlantic and Owl Ventures\nPrivate Equity 500,000,000\n2 12/09/2020 mCaffeine Personal Care Skincare & Haircare Mumbai Amicus Capital Private Equity I LLP, Amicus Capital Partners India Fund I and RP-SG Venture Fund 1 Series B 3,000,000\n3 09/09/2020 Qshala EduTech Online Curiosity Platform for Kids Bangalore Rainmatter Capital Angel 370,000\n4 02/09/2020 Winzo Online Gaming Online Gaming New Delhi Kalaari Capital Partners, IndigoEdge Management Consultancy Series B 15,500,000\n5 09/09/2020 Hippo Video Video Customer Experience(CX) Platform Video Customer Experience(CX) Platform Newark, Delaware, United States of Amercia Alpha Wave Incubation, Exfinity Venture Partners and existing backers.\nSeries A 4,500,000\n6 07/09/2020 Melorra E-commerce Online Jewelry St
# ...

# %%
#import all the required libraries
import pandas as pd
import selenium
from selenium.webdriver.common.by import By
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# %%
import requests
from selenium import webdriver

browser = webdriver.Chrome()

browser.get("https://www.digit.in/top-products/best-gaming-laptops-40.html")
browser.maximize_window()

# %%
browser.maximize_window()
title_tags = browser.find_elements(By.XPATH,"//div[@class='TopNumbeHeading active sticky-footer']")
title_tags
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="6ddabaeef259e9f6e5a1d10c4e54b30a", element="ead13eee-ace9-4db4-b71a-f61fafba364a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6ddabaeef259e9f6e5a1d10c4e54b30a", element="06a04155-9eed-491f-8b42-15a8bceb481f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6ddabaeef259e9f6e5a1d10c4e54b30a", element="c2b983f9-10df-4127-bfb5-ffac77121918")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6ddabaeef259e9f6e5a1d10c4e54b30a", element="0768071b-be62-4c7a-81b3-ad16d5ac4ebf")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6ddabaeef259e9f6e5a1d10c4e54b30a", element="d8e602b5-c148-46b0-925d-657038e73f75")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6ddabaeef259e9f6e5a1d10c4e54b30a", element="16bb4255-ec21-4158-9b37-224dfb736b54")>,
# ...

# %%
titles=[]
for i in title_tags:
    title=i.text
    titles.append(title)
titles
# Out:
# ['1.\nACER NITRO 5',
#  '2.\nMSI STEALTH 15M',
#  '3.\nASUS ROG STRIX SCAR 15',
#  '4.\nALIENWARE AREA 51M R2',
#  '5.\nALIENWARE M15 R3',
#  '6.\nASUS ROG STRIX SCAR 15',
#  '7.\nASUS ZEPHYRUS G14',
#  '8.\nLENOVO LEGION 5I',
#  '9.\nASUS ROG ZEPHYRUS DUO 15',
#  '10.\nACER ASPIRE 7 GAMING LAPTOP']

# %%
windows_tags = browser.find_elements(By.XPATH,"//div[@class='product-detail']")
windows_tags
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="6ddabaeef259e9f6e5a1d10c4e54b30a", element="958237dc-1308-45d2-a823-05db0b2228b9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6ddabaeef259e9f6e5a1d10c4e54b30a", element="8cc0effa-ec67-4996-a28c-22d1742c9f53")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6ddabaeef259e9f6e5a1d10c4e54b30a", element="637df893-a35a-430a-a5a1-1fe30dd5e034")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6ddabaeef259e9f6e5a1d10c4e54b30a", element="01205e8e-b977-4aa8-81c5-4b540ee9ecc6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6ddabaeef259e9f6e5a1d10c4e54b30a", element="0f9c19c8-b4b4-44aa-8c8c-48caecc23f33")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="6ddabaeef259e9f6e5a1d10c4e54b30a", element="4500fd76-908c-4bf1-bdfb-478274f82748")>,
# ...

# %%
productdetail=[]
for i in windows_tags:
    wind=i.text
    productdetail.append(wind)
productdetail
# Out:
# ['OS\nWINDOWS 10\nDISPLAY\n15.6" (1920 X 1080)\nPROCESSOR\nAMD RYZEN 9 OCTA CORE | 2.4 GHZ\nMEMORY\n1 TB HDD/16 GBGB DDR4\nFULL SPECS OTHER ACER LAPTOPS',
#  'OS\nWINDOWS 10\nDISPLAY\n15.6" (1920 X 1080)\nPROCESSOR\nINTEL CORE I7 11TH GEN - 11375H | NA\nMEMORY\n1 TB SSD/16 GBGB DDR4\nFULL SPECS OTHER MSI LAPTOPS',
#  'OS\nWINDOWS 10\nDISPLAY\n15.6" (2560 X 1440)\nPROCESSOR\nAMD RYZEN 9 OCTA CORE - 5900HX | 3.3 GHZ\nMEMORY\n2 TB SSD/32 GBGB DDR4\nFULL SPECS OTHER ASUS LAPTOPS',
#  'OS\nWINDOWS 10 HOME\nDISPLAY\n17.3" (1920 X 1080)\nPROCESSOR\n10TH GEN INTEL® CORE™ I7-10700 | 2.90 GHZ\nMEMORY\n1 TB SSD/16 GBGB DDR4\nFULL SPECS OTHER ALIENWARE LAPTOPS',
#  'OS\nWINDOWS 10 HOME\nDISPLAY\n15.6" (3840 X 2160)\nPROCESSOR\n10TH GEN INTEL® CORE™ I9-10980HK | NA\nMEMORY\n1 TB SSD/16 GBGB DDR4\nFULL SPECS OTHER ALIENWARE LAPTOPS',
# ...

# %%
urls=browser.find_elements(By.XPATH,"//div[@class='product-ickon']/img")
UR=[]
for i in urls:
    UR.append(i.get_attribute('src'))
UR
# Out:
# ['https://static.digit.in/product/thumb_200018_product_td_300.jpeg',
#  'https://www.digit.in/images/digit_topten_icon.png',
#  'https://www.digit.in/images/digit_topten_icon.png',
#  'https://www.digit.in/images/digit_topten_icon.png',
#  'https://www.digit.in/images/digit_topten_icon.png',
#  'https://www.digit.in/images/digit_topten_icon.png',
#  'https://www.digit.in/images/digit_topten_icon.png',
#  'https://www.digit.in/images/digit_topten_icon.png',
#  'https://www.digit.in/images/digit_topten_icon.png',
#  'https://www.digit.in/images/digit_topten_icon.png']

# %%
import pandas as pd #for data visualization
digit=pd.DataFrame({})
digit['titles']=titles
digit['productdetail']=productdetail
digit['imageurl']=UR
digit
# Out:
#                              titles  \
# 0                  1.\nACER NITRO 5
# 1               2.\nMSI STEALTH 15M
# 2        3.\nASUS ROG STRIX SCAR 15
# 3         4.\nALIENWARE AREA 51M R2
# 4              5.\nALIENWARE M15 R3
# 5        6.\nASUS ROG STRIX SCAR 15
# 6             7.\nASUS ZEPHYRUS G14
# 7              8.\nLENOVO LEGION 5I
# 8      9.\nASUS ROG ZEPHYRUS DUO 15
# 9  10.\nACER ASPIRE 7 GAMING LAPTOP
#
#                                        productdetail  \
# 0  OS\nWINDOWS 10\nDISPLAY\n15.6" (1920 X 1080)\n...
# 1  OS\nWINDOWS 10\nDISPLAY\n15.6" (1920 X 1080)\n...
# 2  OS\nWINDOWS 10\nDISPLAY\n15.6" (2560 X 1440)\n...
# 3  OS\nWINDOWS 10 HOME\nDISPLAY\n17.3" (1920 X 10...
# 4  OS\nWINDOWS 10 HOME\nDISPLAY\n15.6" (3840 X 21...
# 5  OS\nWINDOWS 10 HOME\nDISPLAY\n15.6" (1920 X 10...
# 6  OS\nWINDOWS 10 HOME\nDISPLAY\n14" (1920 X 1080...
# 7  OS\nWINDOWS 10 PRO\nDISPLAY\n15.6" (1920 X 108...
# 8  OS\nWINDOWS 10\nDISPLAY\n15.6" (3840 X 1100)\n...
# ...

# %% [markdown]
# # 8. Write a python program to scrape the details for all billionaires from www.forbes.com. Details to be
# scrapped: “Rank”, “Name”, “Net worth”, “Age”, “Citizenship”, “Source”, “Industry”.

# %%
#import all the required libraries
import pandas as pd
import selenium
from selenium.webdriver.common.by import By
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# %%
import requests
from selenium import webdriver

browser = webdriver.Chrome()

browser.get("https://www.forbes.com/real-time-billionaires/#6f1445f93d78")
browser.maximize_window()

# %%
Rank = browser.find_elements(By.XPATH,"//td[@class='rank']")
len(Rank)
# Out:
# 25

# %%
Ranks = []
for i in Rank:
    Ranks.append(i.text)

# %%
Name = browser.find_elements(By.XPATH,"//td[@class='name']")
len(Name)
# Out:
# 25

# %%
Names = []
for i in Name:
    Names.append(i.text)

# %%
worth = browser.find_elements(By.XPATH,"//td[@class='Net Worth']")
len(worth)
# Out:
# 25

# %%
Net_worth = []
for i in worth:
    Net_worth.append(i.text)
Age = browser.find_elements(By.XPATH,"//td[@class='age']")
len(Age)
# Out:
# 25

# %%
Age_of_Billionaire = []
for i in Age:
    Age_of_Billionaire.append(i.text)
Source = browser.find_elements(By.XPATH,"//td[@class='source']")
len(Source)
# Out:
# 25

# %%
Source_of_Billionaire = []
for i in Source:
    Source_of_Billionaire.append(i.text)
Country = browser.find_elements(By.XPATH,"//td[@class='Country/Territory']")
len(Country)
# Out:
# 25

# %%
Country_of_Billionaire = []
for i in Country:
    Country_of_Billionaire.append(i.text)

# %%
import pandas as pd
Billionare=pd.DataFrame({})
Billionare['Rank']= Ranks
Billionare['Name']= Names
Billionare['Networth']= Net_worth
Billionare['Age']= Age_of_Billionaire
Billionare['Source']= Source_of_Billionaire
Billionare['Country']= Country_of_Billionaire

# %%
Billionare.head()
# Out:
#   Rank                      Name  Networth Age              Source  \
# 0    1                 Elon Musk  $239.0 B  50       Tesla, SpaceX
# 1    2                Jeff Bezos  $178.0 B  58              Amazon
# 2    3  Bernard Arnault & family  $172.0 B  72                LVMH
# 3    4                Bill Gates  $131.4 B  66           Microsoft
# 4    5            Warren Buffett  $117.1 B  91  Berkshire Hathaway
#
#          Country
# 0  United States
# 1  United States
# 2         France
# 3  United States
# 4  United States

# %% [markdown]
# # 9. Write a program to extract at least 500 Comments, Comment upvote and time when comment was posted
# from any YouTube Video.

# %%
#import all the required libraries
import pandas as pd
import selenium
from selenium.webdriver.common.by import By
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# %%
import requests
from selenium import webdriver

browser = webdriver.Chrome()

browser.get("https://www.youtube.com/watch?v=YfO28Ihehbk")
browser.maximize_window()
browser.execute_script("window.scrollBy(0,10000)" "")

# %%
browser.execute_script("window.scrollBy(0,10000)" "")

# %%
for i in range(200):
    browser.execute_script("window.scrollBy(0,10000)" "")

# %%
Comment = browser.find_elements(By.ID,"content-text")
len(Comment)
# Out:
# 0

# %%
Comments = []
for i in Comment:
    Comments.append(i.text)
Comments
# Out:
# []

# %%
upvote = browser.find_elements(By.ID,"vote-count-middle")
len(upvote)
# Out:
# 0

# %%
votes = []
for i in upvote:
    votes.append(i.text)
votes
# Out:
# []

# %%
ago = browser.find_elements(By.XPATH,"//*[@id='header-author']/yt-formatted-string/a")
len(ago)
# Out:
# 20

# %%
time = []
for i in ago:
    time.append(i.text)
time
# Out:
# ['2 years ago',
#  '8 months ago',
#  '1 year ago',
#  '1 year ago',
#  '1 year ago',
#  '1 year ago',
#  '9 months ago (edited)',
#  '6 months ago (edited)',
#  '1 year ago',
#  '2 years ago',
#  '1 year ago',
#  '1 year ago',
#  '1 year ago',
#  '2 years ago',
#  '1 year ago',
#  '2 years ago',
#  '4 months ago',
#  '11 months ago',
#  '1 year ago (edited)',
#  '1 year ago']

# %%
import pandas as pd
youtube=pd.DataFrame({})
youtube['comments']= Comments
youtube['upvote']= votes
youtube['ago']= time

# %%
youtube.head()
# Out:
#    comments  upvote           ago
# 0       NaN     NaN   2 years ago
# 1       NaN     NaN  8 months ago
# 2       NaN     NaN    1 year ago
# 3       NaN     NaN    1 year ago
# 4       NaN     NaN    1 year ago

# %%
#import all the required libraries
import pandas as pd
import selenium
from selenium.webdriver.common.by import By
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# %%
import requests
from selenium import webdriver

browser = webdriver.Chrome()

browser.get("https://www.hostelworld.com/s?q=London,%20England&country=England&city=London&type=city&id=3&from=2021-07-23&to=2021-07-26&guests=2&page=1")
browser.maximize_window()

# %%
name = browser.find_elements(By.XPATH,"//h2[@class='title title-6']/a")
hotel_name = []
for i in name:
    hotel_name.append(i.text)
name
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="fb6bf1cb2465de699a6a4f0667daaad7", element="a055671c-4502-4009-8ed8-beebc5934e65")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fb6bf1cb2465de699a6a4f0667daaad7", element="f3be6650-4ea2-44b9-926d-7320b083c6f6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fb6bf1cb2465de699a6a4f0667daaad7", element="e43405bc-f7a4-4cc8-9c62-8b7486f0749f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fb6bf1cb2465de699a6a4f0667daaad7", element="4c638d9e-69c8-43ea-87db-d981480de028")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fb6bf1cb2465de699a6a4f0667daaad7", element="aad1b9b2-1099-4704-811f-a9559dc54c63")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fb6bf1cb2465de699a6a4f0667daaad7", element="da7d6bb7-5ac3-4e53-a52e-711dd9b30355")>,
# ...

# %%
distance = browser.find_elements(By.CLASS_NAME,'description')

# %%
distance_from_city = []
for i in distance:
    distance_from_city.append(i.text)
distance_from_city
# Out:
# ['Hostel - 1.8km from city centre',
#  'Hostel - 3km from city centre',
#  'Hostel - 1.7km from city centre',
#  'Hostel - 5.4km from city centre',
#  'Hostel - 2.6km from city centre',
#  'Hostel - 1.8km from city centre',
#  'Hostel - 5.5km from city centre',
#  'Hostel - 5.9km from city centre',
#  'Hostel - 1.3km from city centre',
#  'Hostel - 3.6km from city centre',
#  'Hostel - 2.1km from city centre',
#  'Hostel - 6.1km from city centre',
#  'Hostel - 0.5km from city centre',
#  'Hostel - 3.3km from city centre',
#  'Hostel - 2.4km from city centre',
#  'Hostel - 3.2km from city centre',
#  'Hostel - 1.8km from city centre',
#  'Hostel - 4.3km from city centre',
#  'Hostel - 7.5km from city centre',
#  'Hostel - 4.1km from city centre',
#  'Hostel - 7.3km from city centre',
#  'Hostel - 7km from city centre',
#  'Hostel - 2.9km from city centre',
#  'Hostel - 5.5km from city centre',
#  'Hostel - 7.6km from city centre',
#  'Hostel - 5.5km from city centre',
# ...

# %%
rat = browser.find_elements(By.XPATH,"//div[@class='score orange big']")

# %%
ratings = []
for i  in rat:
    try:
        ratings.append(i.text)
    except NoSuchElementException as E:
        ratings.append("__")
ratings
# Out:
# ['8.2',
#  '7.8',
#  '8.0',
#  '9.6',
#  '6.7',
#  '8.2',
#  '9.3',
#  '8.0',
#  '7.6',
#  '8.9',
#  '9.6',
#  '7.3',
#  '7.8',
#  '9.3',
#  '8.4',
#  '8.5',
#  '8.0',
#  '7.4',
#  '8.0',
#  '7.4',
#  '7.0',
#  '7.5',
#  '9.0',
#  '9.2',
#  '7.3',
#  '7.8',
#  '7.9',
#  '7.9',
#  '8.3',
#  '6.1']

# %%
total_rates = browser.find_elements(By.XPATH,"//div[@class='reviews']")

# %%
total_rating =[]
for i in total_rates:
    total_rating.append(i.text)
total_rating
# Out:
# ['11005 Total Reviews',
#  '6817 Total Reviews',
#  '4061 Total Reviews',
#  '202 Total Reviews',
#  '9578 Total Reviews',
#  '3262 Total Reviews',
#  '1692 Total Reviews',
#  '1115 Total Reviews',
#  '809 Total Reviews',
#  '13411 Total Reviews',
#  '4508 Total Reviews',
#  '1068 Total Reviews',
#  '239 Total Reviews',
#  '2797 Total Reviews',
#  '195 Total Reviews',
#  '379 Total Reviews',
#  '622 Total Reviews',
#  '3738 Total Reviews',
#  '3977 Total Reviews',
#  '34 Total Reviews',
#  '3680 Total Reviews',
#  '647 Total Reviews',
#  '4709 Total Reviews',
#  '16 Total Reviews',
#  '3156 Total Reviews',
#  '1317 Total Reviews',
#  '228 Total Reviews',
#  '111 Total Reviews',
#  '855 Total Reviews',
#  '3613 Total Reviews']

# %%
over_all = browser.find_elements(By.XPATH,"//div[@class='keyword']")

# %%
over_all_review =[]
for i in over_all:
    over_all_review.append(i.text)

over_all_review
# Out:
# ['Fabulous',
#  'Fabulous',
#  'Very Good',
#  'Fabulous',
#  'Superb',
#  'Good',
#  'Fabulous',
#  'Superb',
#  'Fabulous',
#  'Very Good',
#  'Fabulous',
#  'Superb',
#  'Very Good',
#  'Very Good',
#  'Superb',
#  'Fabulous',
#  'Fabulous',
#  'Fabulous',
#  'Very Good',
#  'Fabulous',
#  'Very Good',
#  'Very Good',
#  'Very Good',
#  'Superb',
#  'Superb',
#  'Very Good',
#  'Very Good',
#  'Very Good',
#  'Very Good',
#  'Fabulous',
#  'Good']

# %%
pp =browser.find_elements(By.XPATH,"//div[@class='price title-5']")

privates_price =[]
for i in pp:
    privates_price.append(i.text)

pp
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="fb6bf1cb2465de699a6a4f0667daaad7", element="67b0ed98-4f43-4543-86b5-7cefefd951d0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fb6bf1cb2465de699a6a4f0667daaad7", element="08a6f3a2-b133-4f3f-b853-0ff84495a3c4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fb6bf1cb2465de699a6a4f0667daaad7", element="a548a937-4eca-4203-a889-ad550cdcd5f0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fb6bf1cb2465de699a6a4f0667daaad7", element="a2c6ec7d-6fab-47dc-a689-98345bb49cb0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fb6bf1cb2465de699a6a4f0667daaad7", element="0fded35d-3bb6-44fc-8f04-84e01fe4d10e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fb6bf1cb2465de699a6a4f0667daaad7", element="44849449-2abc-4758-b049-69ab84f2ee6e")>,
# ...

# %%
privates_price = privates_price[0::2]

# %%
dp =browser.find_elements(By.XPATH,"//div[@class='price title-5']")

dorms_price =[]
for i in dp:
    dorms_price.append(i.text)

dp
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="fb6bf1cb2465de699a6a4f0667daaad7", element="67b0ed98-4f43-4543-86b5-7cefefd951d0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fb6bf1cb2465de699a6a4f0667daaad7", element="08a6f3a2-b133-4f3f-b853-0ff84495a3c4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fb6bf1cb2465de699a6a4f0667daaad7", element="a548a937-4eca-4203-a889-ad550cdcd5f0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fb6bf1cb2465de699a6a4f0667daaad7", element="a2c6ec7d-6fab-47dc-a689-98345bb49cb0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fb6bf1cb2465de699a6a4f0667daaad7", element="0fded35d-3bb6-44fc-8f04-84e01fe4d10e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fb6bf1cb2465de699a6a4f0667daaad7", element="44849449-2abc-4758-b049-69ab84f2ee6e")>,
# ...

# %%
dorms_price = dorms_price[1::2]

# %%
desc =browser.find_elements(By.XPATH,"//div[@class='rating-factors prop-card-tablet rating-factors small']")

description =[]
for i in desc:
    description.append(i.text)
    
desc
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="fb6bf1cb2465de699a6a4f0667daaad7", element="b967d4ae-1568-4aaf-9a6e-e44a82847bbf")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fb6bf1cb2465de699a6a4f0667daaad7", element="e99309ee-828f-4d06-95b3-f410c0fe7fa9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fb6bf1cb2465de699a6a4f0667daaad7", element="cb3d9ca2-018b-40d3-a74f-ba1426ea1f8d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fb6bf1cb2465de699a6a4f0667daaad7", element="1367c833-fa41-4c23-96de-74b6503ac4cd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fb6bf1cb2465de699a6a4f0667daaad7", element="44d4907f-842a-48de-b08d-688795164e6a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fb6bf1cb2465de699a6a4f0667daaad7", element="5d522416-ab57-4241-9fcc-f1976ad19105")>,
# ...

# %%
fasc =browser.find_elements(By.XPATH,"//div[@class='facilities-label facilities']")

facilities =[]
for i in fasc:
    facilities.append(i.text)

fasc
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="fb6bf1cb2465de699a6a4f0667daaad7", element="006eb8fc-b3aa-4613-bd93-98238a15b718")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fb6bf1cb2465de699a6a4f0667daaad7", element="b9b20b85-69bb-4124-ab16-7fada7f58ba9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fb6bf1cb2465de699a6a4f0667daaad7", element="cefe035b-647d-4b14-b660-9aee4b6be74b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fb6bf1cb2465de699a6a4f0667daaad7", element="81da8008-f10e-4244-807d-8bdb8120c37f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fb6bf1cb2465de699a6a4f0667daaad7", element="acab47c4-6eb7-4af7-a090-034fa38edb8d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fb6bf1cb2465de699a6a4f0667daaad7", element="5b35e529-8eef-4ebb-b16a-85ac067ad4e8")>,
# ...

# %%
df=pd.DataFrame({'Hostel_Name':hotel_name,'Distance_from_city ':distance_from_city ,'Ratings':ratings,'Total_reviews':total_rating,})
df
# Out:
#                                 Hostel_Name              Distance_from_city   \
# 0                  St Christopher's Village  Hostel - 1.8km from city centre
# 1                          Generator London    Hostel - 3km from city centre
# 2         Safestay London Elephant & Castle  Hostel - 1.7km from city centre
# 3                      Urbany Hostel London  Hostel - 5.4km from city centre
# 4               Smart Russell Square Hostel  Hostel - 2.6km from city centre
# 5      St Christopher's Inn - London Bridge  Hostel - 1.8km from city centre
# 6                  Barmy Badger Backpackers  Hostel - 5.5km from city centre
# 7   Safestay London Kensington Holland Park  Hostel - 5.9km from city centre
# 8                        Strand Continental  Hostel - 1.3km from city centre
# 9           Wombat's The City Hostel London  Hostel - 3.6km from city centre
# 10                 YHA London Oxford Street  Hostel - 2.1km from city centre
# ...
